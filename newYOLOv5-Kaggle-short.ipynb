# %% [markdown]
#  # TRAINING RESULTS of THREE MODELS: YOLOv5s-baseline, YOLOv5s-C3CA and YOLOV5s-CA

# %%
# Train YOLOv5s-baseline on Kaggle facemask dataset for 300 epochs
# !python train.py --img 640 --batch 16 --epochs 300 --data ./Kaggle-mask-detection-dataset/data/data.yaml --hyp ./data/hyps/hyp.scratch-high.yaml --cfg ./models/yolov5s.yaml --weights "" --cache
# Out:
# train: weights=, cfg=./models/yolov5s.yaml, data=./Kaggle-mask-detection-dataset/data/data.yaml, hyp=./data/hyps/hyp.scratch-high.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# Python 3.7.0 required by YOLOv5, but Python 3.6.13 is currently installed
# fatal: not a git repository (or any parent up to mount point /media/intown)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# ...

# %%
# Train YOLOv5s-C3CA Kaggle facemask dataset for 300 epochs
# !python -m torch.distributed.launch --nproc_per_node 2 train.py --device 0,1 --img 640 --batch 16 --epochs 300 --data ./Kaggle-mask-detection-dataset/data/data_kaggle.yaml --hyp ./data/hyps/hyp.scratch-high.yaml --cfg ./models/hub/yolov5s-C3CABlock.yaml --weights "" --cache
# Out:
# /home/intown/anaconda3/envs/yolov5/lib/python3.6/site-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# fatal: not a git repository (or any parent up to mount point /media/intown)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# ...

# %%
# Train YOLOv5s-CA on Kaggle facemask dataset for 300 epochs
# !python -m torch.distributed.launch --nproc_per_node 2 train.py --device 0,1 --img 640 --batch 16 --epochs 300 --data ./Kaggle-mask-detection-dataset/data/data_kaggle.yaml --hyp ./data/hyps/hyp.scratch-high.yaml --cfg ./models/hub/yolov5s-CA-v2.yaml --weights "" --cache
# Out:
# /home/intown/anaconda3/envs/yolov5/lib/python3.6/site-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# fatal: not a git repository (or any parent up to mount point /media/intown)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# ...

# %% [markdown]
# # VAL Results on IWM images of FMLD

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python val.py --img 640 --batch 16 --device 0,1 --data ./data_fmld_IWM.yaml --weights ./runs/train/exp70/weights_5s/best.pt
# Out:
# val: data=./data_fmld_IWM.yaml, weights=['./runs/train/exp70/weights_5s/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=0,1, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# Python 3.7.0 required by YOLOv5, but Python 3.6.13 is currently installed
# fatal: not a git repository (or any parent up to mount point /media/intown)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# YOLOv5 🚀 2022-4-7 torch 1.10.1+cu102 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11019MiB)
#                                       CUDA:1 (NVIDIA GeForce RTX 2080 Ti, 11019MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning '/media/intown/2a576e61-c809-4108-bdaf-549531794dc1/yolov5-master/
# ...

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python val.py --img 640 --batch 16 --device 0,1 --data ./data_fmld_IWM.yaml --weights ./runs/train/exp88/weights/best.pt
# Out:
# val: data=./data_fmld_IWM.yaml, weights=['./runs/train/exp88/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=0,1, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# Python 3.7.0 required by YOLOv5, but Python 3.6.13 is currently installed
# fatal: not a git repository (or any parent up to mount point /media/intown)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# YOLOv5 🚀 2022-4-7 torch 1.10.1+cu102 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11019MiB)
#                                       CUDA:1 (NVIDIA GeForce RTX 2080 Ti, 11019MiB)
#
# Fusing layers...
# YOLOv5s-CA summary: 276 layers, 6419264 parameters, 0 gradients
# val: Scanning '/media/intown/2a576e61-c809-4108-bdaf-549531794dc1/yolov5-master/
# ...

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python val.py --img 640 --batch 16 --device 0,1 --data ./data_fmld_IWM.yaml --weights ./runs/train/exp87/weights/best.pt
# Out:
# val: data=./data_fmld_IWM.yaml, weights=['./runs/train/exp87/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=0,1, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# Python 3.7.0 required by YOLOv5, but Python 3.6.13 is currently installed
# fatal: not a git repository (or any parent up to mount point /media/intown)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# YOLOv5 🚀 2022-4-7 torch 1.10.1+cu102 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11019MiB)
#                                       CUDA:1 (NVIDIA GeForce RTX 2080 Ti, 11019MiB)
#
# Fusing layers...
# YOLOv5s-CA-v2 summary: 221 layers, 7042824 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning '/media/intown/2a576e61-c809-4108-bdaf-549531794dc1/yolov5-master/
# ...
